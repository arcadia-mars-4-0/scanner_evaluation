# %%
from huggingface_hub import hf_hub_download, snapshot_download

# Single file
# path = hf_hub_download(repo_id="arcadia-mars-4-0/abc-scout-scanners", filename="data.parquet", repo_type="dataset")

# Entire repo
snapshot_download(repo_id="arcadia-mars-4-0/abc-scout-scanners", repo_type="dataset", local_dir="./hf_data")

# example code for reading from dif location
# scout view -T scanner_pilot/hf_data/eval-logs --scans scanner_pilot/hf_data/xstest/scan-results
# scout view -T scanner_pilot/hf_data/eval-logs/xstest/ --scans scanner_pilot/hf_data/scan-results/xstest/
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %%
# --- Uploading results ----
from pathlib import PurePosixPath

from inspect_ai.log import read_eval_log, write_eval_log

log_file = "core_bench/eval-logs/2026-02-27T20-08-12+00-00_core-bench_ZvU684YYCTbNLk8jJyRdRM.eval"
log = read_eval_log(log_file)
task_name = log.eval.task.split("/")[-1]
filename = PurePosixPath(log_file).name

write_eval_log(
    log,
    location=f"hf://datasets/arcadia-mars-4-0/abc-scout-scanners/{task_name}/eval-logs/{filename}",
)

from pathlib import Path
from inspect_ai._util.file import copy_file

scan_results_base = Path("core_bench/scan-results")
hf_base = "hf://datasets/arcadia-mars-4-0/abc-scout-scanners"

# Derive task name from the parent directory (mirrors eval log upload above)
task_name = scan_results_base.parent.name

for scan_dir in sorted(scan_results_base.glob("scan_id=*")):
    scan_id = scan_dir.name  # e.g. "scan_id=bEiv4f9xi3Kp4VNYo9a9wJ"
    for src_file in sorted(scan_dir.iterdir()):
        dst = f"{hf_base}/{task_name}/scan-results/{scan_id}/{src_file.name}"
        print(f"Uploading {src_file.relative_to(scan_results_base.parent)} → {dst}")
        copy_file(str(src_file), dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       4 from inspect_ai.log import read_eval_log, write_eval_log
#       6 log_file = "core_bench/evallogs/2026-02-27T20-08-12+00-00_core-bench_ZvU684YYCTbNLk8jJyRdRM.eval"
# ----> 7 log = read_eval_log(log_file)
#       8 task_name = log.eval.task.split("/")[-1]
#       9 filename = PurePosixPath(log_file).name
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/log/_file.py:279, in read_eval_log(log_file, header_only, resolve_attachments, format)
#     273     raise RuntimeError(
#     274         "read_eval_log cannot be called from a trio async context (please use read_eval_log_async instead)"
#     275     )
#     277 # will use s3fs and is not called from main inspect solver/scorer/tool/sandbox
#     278 # flow, so force the use of asyncio
# --> 279 return run_coroutine(
#     280     read_eval_log_async(
#     281         log_file,
#     282         header_only,
#     283         resolve_attachments,
#     284         format,
#     285     )
#     286 )
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:120, in run_coroutine(coroutine)
#     118 if running_in_notebook():
#     119     init_nest_asyncio()
# --> 120     result = asyncio.run(coroutine)
#     121     return result
#     122 else:
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115, in run(main, debug, loop_factory)
#     113 task = asyncio.ensure_future(main, loop=loop)
#     114 try:
# --> 115     return loop.run_until_complete(task)
#     116 finally:
#     117     if not task.done():
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/nest_asyncio2.py:230, in _patch_loop.<locals>.run_until_complete(self, future)
#     227 if self._ready:
#     228     self._run_once()
# --> 230 return f.result()
#
# File /usr/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /usr/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/log/_file.py:340, in read_eval_log_async(log_file, header_only, resolve_attachments, format, async_fs)
#     338     else:
#     339         recorder_type = recorder_type_for_format(format)
# --> 340     log = await recorder_type.read_log(log_file, header_only, async_fs)
#     342 # resolve attachement if requested
#     343 if resolve_attachments and log.samples:
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/log/_recorders/eval.py:213, in EvalRecorder.read_log(cls, location, header_only, async_fs)
#     211 else:
#     212     async with AsyncFilesystem() as owned_fs:
# --> 213         return await cls._read_log_impl(location, header_only, owned_fs)
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/log/_recorders/eval.py:242, in EvalRecorder._read_log_impl(cls, location, header_only, async_fs)
#     240 read_location = temp_log or location
#     241 reader = AsyncZipReader(async_fs, read_location)
# --> 242 cd = await reader.entries()
#     243 log = await _read_log(reader, cd.entries, location, header_only)
#     245 if etag is not None:
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/async_zip.py:343, in AsyncZipReader.entries(self)
#     341 """Load and cache the central directory."""
#     342 if self._central_directory is None:
# --> 343     self._central_directory = await _get_central_directory(
#     344         self._filesystem, self._filename
#     345     )
#     346 return self._central_directory
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/async_zip.py:48, in _get_central_directory(filesystem, filename)
#      45 async def _get_central_directory(
#      46     filesystem: AsyncFilesystem, filename: str
#      47 ) -> CentralDirectory:
# ---> 48     return await _parse_central_directory(filesystem, filename)
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/async_zip.py:149, in _parse_central_directory(filesystem, filename)
#     141 async def _parse_central_directory(
#     142     filesystem: AsyncFilesystem, filename: str
#     143 ) -> CentralDirectory:
#     144     """Parse the central directory and return all entries.
#     145
#     146     Returns:
#     147         CentralDirectory with entries and etag.
#     148     """
# --> 149     cd_loc = await _find_central_directory(filesystem, filename)
#     151     # Reuse the tail buffer if the central directory falls within it
#     152     if cd_loc.offset >= cd_loc.tail_start:
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/async_zip.py:64, in _find_central_directory(filesystem, filename)
#      51 async def _find_central_directory(
#      52     filesystem: AsyncFilesystem, filename: str
#      53 ) -> CentralDirectoryLocation:
#      54     """Locate and parse the central directory metadata.
#      55
#      56     Uses a suffix range request to avoid a separate HEAD for the file size.
#    (...)     62         ValueError: If EOCD signature not found or ZIP64 structure is corrupt
#      63     """
# ---> 64     suffix = await filesystem.read_file_suffix(filename, 65536)
#      65     tail = suffix.data
#      66     tail_start = suffix.file_size - len(tail)
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/asyncfiles.py:240, in AsyncFilesystem.read_file_suffix(self, filename, suffix_length)
#     232         return await anyio.to_thread.run_sync(
#     233             s3_read_file_suffix,
#     234             self.s3_client(),
#    (...)    237             suffix_length,
#     238         )
#     239 else:
# --> 240     file_size = filesystem(filename).info(filename).size
#     241     start = max(0, file_size - suffix_length)
#     242     data = await self.read_file_bytes_fully(filename, start, file_size)
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/inspect_ai/_util/file.py:212, in FileSystem.info(self, path, **kwargs)
#     211 def info(self, path: str, **kwargs: dict[str, Any]) -> FileInfo:
# --> 212     return self._file_info(self.fs.info(path, **kwargs))
#
# File ~/projects/scanner_evaluation/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py:101, in LocalFileSystem.info(self, path, **kwargs)
#      98 else:
#      99     # str or path-like
#     100     path = self._strip_protocol(path)
# --> 101     out = os.stat(path, follow_symlinks=False)
#     102     link = stat.S_ISLNK(out.st_mode)
#     103     if link:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jeffm/projects/scanner_evaluation/evals/core_bench/evallogs/2026-02-27T20-08-12+00-00_core-bench_ZvU684YYCTbNLk8jJyRdRM.eval'
